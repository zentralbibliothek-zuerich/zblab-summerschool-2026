# %% [markdown]
# # Setup
#
# <a target="_blank" href="https://colab.research.google.com/github/pleyad/Summer-School-2026/blob/main/notebooks/00_setup.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# This notebook is used for smoke testing the coding setup at the ZB Summer School 2026.
